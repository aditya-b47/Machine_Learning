# %%
import random
import matplotlib.pyplot as plt

# %%
#random.random()
random.seed(1)
(5*random.random(),5*random.random(),5*random.random(),5*random.random(),5*random.random())
# Out:
# (0.6718212205620061,
#  4.237168684686163,
#  3.8188730948830703,
#  1.2753451286971085,
#  2.4771754354597046)

# %%
random.seed(1)
(5*random.random(),5*random.random(),5*random.random(),5*random.random(),5*random.random())
# Out:
# (0.6718212205620061,
#  4.237168684686163,
#  3.8188730948830703,
#  1.2753451286971085,
#  2.4771754354597046)

# %%
# create a dice that generate random numbers 1,2,3,4,5,6

for i in range(100):
  num = int(6*random.random()) + 1  # this +1 will remove the zero  because 0 will be added by 1
  print(num)
# Out:
# 3
# 5
# 2
# 6
# 6
# 1
# 1
# 4
# 6
# 3
# 2
# 3
# 1
# 2
# 3
# 3
# 2
# 2
# 2
# 3
# 2
# 1
# 6
# 4
# 4
# 2
# 6
# 6
# 1
# 2
# 5
# 5
# 6
# 3
# 5
# 5
# 2
# 4
# 6
# 6
# 4
# 4
# 1
# 2
# 5
# 3
# 2
# 4
# 5
# 5
# 3
# 3
# 4
# 5
# 4
# 3
# 3
# 1
# 1
# 5
# 6
# 4
# 3
# 2
# 4
# 6
# 5
# 4
# 6
# 2
# 4
# 6
# 4
# 3
# 2
# 4
# 6
# 1
# 5
# 5
# 6
# 5
# 5
# 4
# 4
# 3
# 1
# 6
# 4
# 2
# 4
# 3
# 3
# 3
# 4
# 4
# 4
# 3
# 1
# 2

# %%
P=(1,2), A=(0,0), B=(5,5)
ax,by = A

# %%
def dist(x1,y1,x2,y2,x3,y3):
  A = (x2-x1)**2+(y2-y1)**2
  B = (x3-x1)**2+(y3-y1)**2
  if A < B:
    return 'A'
  elif A > B:
    return 'B'
  else:
    return 'Equal'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(dist((1, 2), (0, 0), (5, 5)))
#
# TypeError: dist() missing 3 required positional arguments: 'y2', 'x3', and 'y3'

# %%
def closer_point(p,a,b):
  """
  p,a,b are (x,y) tuples.
  Returns 'A' if p is closer to a,'B' if closer to b, 'Equal' if tied.
  """
