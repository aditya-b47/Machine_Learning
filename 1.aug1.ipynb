# %%
1+1
# Out:
# 2

# %%
x=10
x*5
# Out:
# 50

# %% [markdown]
# # log is basically number of zeros.
# log(10) -> 1
# log(100) -> 2
# log(1000) -> 3
# log(10**n) -> n
# alog(2) -> 10**2 (10 power 2)
#
# #log(something) = 5
# what is something?
# 10**5

# %%
import math
math.log10(10)

math.log(25 ,5)
# Out:
# 2.0

# %%
math.log(27,3)
# Out:
# 3.0

# %%
math.log(9*27, 3)
# Out:
# 4.999999999999999

# %%
from math import *
log(125, 5)
# Out:
# 3.0000000000000004

# %%
10**.5
# Out:
# 3.1622776601683795

# %%
log10(3.1622776601683795)
# Out:
# 0.5

# %% [markdown]
# 5**0 -> 1
# 5**1-> 5
# 5**2->25

# %%
5**6
# Out:
# 15625

# %%
log(15625 ,5)
# Out:
# 6.000000000000001
