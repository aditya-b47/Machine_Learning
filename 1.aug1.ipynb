# %%
1+1
# Out:
# 2

# %%
x=10
x*5
# Out:
# 50

# %% [markdown]
# # log is basically number of zeros.
# log(10) -> 1
# log(100) -> 2
# log(1000) -> 3
# log(10**n) -> n
# alog(2) -> 10**2 (10 power 2)
#
# #log(something) = 5
# what is something?
# 10**5

# %%
import math
math.log10(10)

math.log(25 ,5)
# Out:
# 2.0

# %%
math.log(27,3)
# Out:
# 3.0

# %%
math.log(9*27, 3)
# Out:
# 4.999999999999999

# %%
from math import *
log(125, 5)
# Out:
# 3.0000000000000004

# %%
10**.5
# Out:
# 3.1622776601683795

# %%
log10(3.1622776601683795)
# Out:
# 0.5

# %% [markdown]
# 5**0 -> 1
# 5**1-> 5
# 5**2->25

# %%
5**6
# Out:
# 15625

# %%
log(15625 ,5)
# Out:
# 6.000000000000001

# %% [markdown]
# # log10(5)

# %%
log10(1)
# Out:
# 0.0

# %%
log10(10)
# Out:
# 1.0

# %%
log10(5)
# Out:
# 0.6989700043360189

# %%
log10(9)
# Out:
# 0.9542425094393249

# %%
guess = 0.9
10**guess
# Out:
# 7.943282347242816

# %%
guess = 0.99
10**guess
# Out:
# 9.772372209558107

# %%
guess = 0.94
10*guess
# Out:
# 9.399999999999999

# %%
hi = 0.99
lo = 0.94
mid = (lo+hi)/2
print(mid)
# Out:
# 0.965

# %%
10**mid
# Out:
# 9.22571427154763

# %%
hi = mid
mid = (lo+hi)/2
print(mid)
# Out:
# 0.9524999999999999

# %%
10**mid
# Out:
# 8.963961859499497

# %%
lo = mid
mid = (lo+mid)/2
print(mid)
# Out:
# 0.9524999999999999
# 8.963961859499497

# %%
10**mid
# Out:
# 8.963961859499497
