# %% [markdown]
# # In this session wwe are going to learn about image manipulation usiong python
#
# 1) A grayScale image is 2D dimension - Width , Height
# 2) A colored Image is 3D dimension - Width , Height , Color
# 3) Video is 4D dimension - Width , Height , Color , Time

# %%
# %pip install matplotlib

# %%
# Color Range is from 0 to 255 0 being the dakest and 255 being the lightest

grey_image = [
  [0,60,255],
  [255,100,0],
  [20,150,200]
]

import matplotlib.pyplot as plt
plt.imshow(grey_image , cmap="grey")

# %%
# 2 x 2 image
red_layer = [
  [0 ,255],
  [160, 80]
]
plt.imshow(red_layer, cmap="grey")

# %%
green_layer = [
  [0 , 255],
  [0, 100]
]
plt.imshow(green_layer, cmap="grey")

# %%
blue_layer = [
  [60,47],
  [255,100]
]
plt.imshow(blue_layer, cmap="grey")

# %%
red_layer = [
  [255 ,0],
  [0, 100]
]
green_layer = [
  [0 , 255],
  [0, 100]
]
blue_layer = [
  [0,0],
  [255,100]
]

colored = [
  [[255,0,0], [0,255,0]],
  [[0,0,255], [100,100,100]]
]
plt.imshow(colored)

# %%
colored = [
  [[255,0,0], [0,255,0], [0,255,255], [0,0,0]],
  [[0,0,255], [255,0,255], [255,255,0], [255,255,255]]
]
plt.imshow(colored)

# %% [markdown]
# # This is an activity where we have downloaded an image and based on that image we are going to find out, how many arrays, height, height, width and numbers are present in the image
#
# we downloaded an image then we used plt.imread library with this we will get all of the image related details

# %%
avenger = plt.imread('avenger.jpeg')
avenger.shape
# Out:
# (544, 367, 3)

# %%
# avenger[0]
# avenger[0][0]
avenger.ndim # tells us the dimensions which is 3 in this case
# Out:
# 3
